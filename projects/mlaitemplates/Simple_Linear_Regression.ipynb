# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# For Simple linear regression with only one dependent variable

# %%
dataset = pd.read_csv("YourFile.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = slr.predict(X_test)

# %%
plt.scatter(X_train,y_train,color = "red")
plt.plot(X_train,slr.predict(X_train), color = 'blue')
plt.title('Title')
plt.xlabel("Independent Variable")
plt.ylabel("Dependent Variable")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.scatter(X_train,y_train,color = "red")
#       2 plt.plot(X_train,slr.predict(X_train), color = 'blue')
#       3 plt.title('Title')
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(X_test,y_test,color = "red")
plt.plot(X_train,slr.predict(X_train), color = 'blue')
plt.title('Salary VS experience')
plt.xlabel("Yrs of Experience")
plt.ylabel("Salary")
plt.show()
